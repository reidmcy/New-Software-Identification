# %%
import simple_id
import pandas
import gensim

target = 'sample.csv'

# %%
df = pandas.read_csv(target)
N = simple_id.loadModel('models/BiRNN-2-128-10.pt')
w2v = gensim.models.Word2Vec.load('models/word2vec.bin')

# %%
r1 = df[df['class'] == 1].iloc[0]
r2 = df[df['class'] == 0].iloc[0]

# %%
simple_id.compareRows([r1, r2], N, w2v, useTitle=True)
plt.show()

# %%
simple_id.compareRows([r1, r2], N, w2v, useTitle=False)
plt.show()
