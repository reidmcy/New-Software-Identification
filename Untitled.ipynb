# %%
import gensim
import pandas
import nltk

import os

dataDir = 'data'
modelsDir = 'models'

littleFile = 'little.tsv'
someFile = 'some.tsv'
mostlyFile = 'mostly.tsv'

w2vFname = 'word2vec.bin'

regenW2V = False

def tokenizer(target):
    return [t for t in nltk.word_tokenize(target.lower()) if t != '.']

def sentinizer(sent):
    return [tokenizer(s) for s in nltk.sent_tokenize(sent)]

def genVecSeq(target, model):
    tokens = tokenizer(target)
    vecs = []
    for t in tokens:
        try:
            vecs.append(model.wv[t])
        except KeyError:
            #print(t)
            pass
    return vecs

def genWord2Vec(*dfs):
    vocab = []
    for df in dfs:
        vocab += list(df['title'].apply(lambda x: x.lower().split()))
        vocab += df['abstract'].apply(sentinizer).sum()

    model = gensim.models.Word2Vec(vocab,
        hs = 1, #Hierarchical softmax is better for infrequent words
        size = 200, #Dim
        window = 5, #Might want to increase this
        min_count = 0,
        max_vocab_size = None,
        workers = 8, #My machine has 8 hyperthreads
        )
    return model

os.makedirs(dataDir, exist_ok = True)
os.makedirs(modelsDir, exist_ok = True)

dfs = {
    'little' : pandas.read_csv('data/little.tsv', sep='\t'),
    'some' : pandas.read_csv('data/some.tsv', sep='\t'),
    'most' : pandas.read_csv('data/mostly.tsv', sep='\t'),
}

if regenW2V:
    print("Generating Word2Vec")
    w2v = genWord2Vec(*dfs.values())
    w2v.save('{}/{}'.format(modelsDir, w2vFname))
else:
    w2v = gensim.models.Word2Vec.load('{}/{}'.format(modelsDir, w2vFname))
print(w2v)
for name, df in dfs.items():
    print("Generating vecs for: {}".format(name))
    df['title_tokenize'] = df['title'].apply(lambda x : genVecSeq(x, w2v))
    df['abstract_tokenize'] = df['abstract'].apply(lambda x : genVecSeq(x, w2v))

#print(dfs['little'])
df = dfs['little']
# Out:
# Word2Vec(vocab=86676, size=200, alpha=0.025)
# Generating vecs for: little
# Generating vecs for: some
# Generating vecs for: most

# %%
import torch 
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable


# Hyper Parameters
sequence_length = 28
input_size = 28
hidden_size = 128
num_layers = 2
num_classes = 10
batch_size = 100
num_epochs = 2
learning_rate = 0.003

# MNIST Dataset
train_dataset = dsets.MNIST(root='./data/',
                            train=True, 
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root='./data/',
                           train=False, 
                           transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
i, l = next(train_loader.__iter__())

# %%
i.view(-1, sequence_length, input_size)
# Out:
# ( 0 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 1 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 2 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
# ...
#
# (97 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# (98 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# (99 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
# [torch.FloatTensor of size 100x28x28]

# %%
m = Variable(i[0].view(-1, sequence_length, input_size))

# %%
m.data.size()
# Out:
# torch.Size([1, 28, 28])

# %%
rnn(Variable(i[0].view(-1, sequence_length, input_size)))
# Out:
# Variable containing:
# 1.00000e-02 *
#   8.8333  6.6464
# [torch.FloatTensor of size 1x2]

# %%
import neuralnet

eta = 0.001
def trainModel(dfPostive, dfNegative):
    dfPostive['vals'] = [np.array([1]) for i in range(len(dfPostive))]
    dfNegative['vals'] = [np.array([0]) for i in range(len(dfNegative))]

    df = dfPostive.append(dfNegative, ignore_index=True)

    from sklearn.utils import shuffle
    df = shuffle(df)


    N = neuralnet.BiRNN(200, 128, 2)
    N.cuda()

    #criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(rnn.parameters(), lr=eta)

    for i in range(100):
        row = np.random.np.random.randint(0, len(df))

        xVec = Variable(torch.from_numpy(np.stack(df['abstract_tokenize'][row])).unsqueeze(0)).cuda()

        yVec = Variable(torch.from_numpy(df['vals'][row])).cuda()
        #print(yVec.data)
            
        optimizer.zero_grad()
        outputs = N(xVec)
        #print(outputs)
        loss = torch.nn.functional.cross_entropy(outputs, yVec)
        loss.backward()
        optimizer.step()
        print(loss.data[0])

# %%
trainModel(dfs['little'], dfs['most'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-b4dd7cb36b7a> in <module>()
# ----> 1 trainModel(dfs['little'], dfs['most'])
#
# <ipython-input-171-1287bafb0631> in trainModel(dfPostive, dfNegative)
#      27
#      28         optimizer.zero_grad()
# ---> 29         outputs = N(xVec)
#      30         #print(outputs)
#      31         loss = torch.nn.functional.cross_entropy(outputs, yVec)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/Reid/Dropbox/Chicago/Spring 2017/Project/neuralnet.py in forward(self, x)
#      26
#      27         # Forward propagate RNN
# ---> 28         out, _ = self.lstm(x, (h0, c0))
#      29
#      30         # Decode hidden state of last time step
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#      89             dropout_state=self.dropout_state
#      90         )
# ---> 91         output, hidden = func(input, self.all_weights, hx)
#      92         if is_packed:
#      93             output = PackedSequence(output, batch_sizes)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     341         else:
#     342             func = AutogradRNN(*args, **kwargs)
# --> 343         return func(input, *fargs, **fkwargs)
#     344
#     345     return forward
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/autograd/function.py in _do_forward(self, *input)
#     271         self._nested_input = input
#     272         flat_input = tuple(_iter_variables(input))
# --> 273         flat_output = super(NestedIOFunction, self)._do_forward(*flat_input)
#     274         nested_output = self._nested_output
#     275         nested_variables = _unflatten(flat_output, self._nested_output)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/autograd/function.py in forward(self, *args)
#     293     def forward(self, *args):
#     294         nested_tensors = _map_variable_tensor(self._nested_input)
# --> 295         result = self.forward_extended(*nested_tensors)
#     296         del self._nested_input
#     297         self._nested_output = result
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward_extended(self, input, weight, hx)
#     283             hy = tuple(h.new() for h in hx)
#     284
# --> 285         cudnn.rnn.forward(self, input, hx, weight, output, hy)
#     286
#     287         self.save_for_backward(input, hx, weight, output)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/backends/cudnn/rnn.py in forward(fn, input, hx, weight, output, hy)
#     237             fn.x_descs = cudnn.descriptor(x[0], fn.seq_length)
#     238             fn.y_descs = cudnn.descriptor(y[0], fn.seq_length)
# --> 239         fn.hx_desc = cudnn.descriptor(hx)
#     240         fn.hy_desc = cudnn.descriptor(hx)
#     241         fn.cx_desc = cudnn.descriptor(cx) if cx is not None else None
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/backends/cudnn/__init__.py in descriptor(tensor, N)
#     308     else:
#     309         descriptor = TensorDescriptor()
# --> 310         descriptor.set(tensor)
#     311     return descriptor
#     312
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/backends/cudnn/__init__.py in set(self, tensor)
#     114         self._stride = tensor.stride()
#     115         check_error(lib.cudnnSetTensorNdDescriptor(
# --> 116             self, _typemap[tensor.type()], tensor.dim(),
#     117             int_array(tensor.size()), int_array(tensor.stride())))
#     118
#
# KeyError: 'torch.FloatTensor'

# %%
torch.from_numpy(np.stack(vecs[0])).unsqueeze(0)
# Out:
# ( 0 ,.,.) =
#   9.1753e-02  1.5142e-01 -5.8268e-01  ...   6.3124e-01  2.1273e-01 -4.8980e-01
#   1.0616e+00  8.1551e-02 -3.5336e-03  ...   5.2598e-01 -1.6134e-01  4.7960e-01
#  -1.7612e-01  5.1657e-01  7.1201e-02  ...   1.7485e+00 -8.2418e-02  8.3827e-01
#                  ...                   ⋱                   ...
#  -6.4270e-01 -2.1115e+00 -4.4894e-02  ...   1.2405e+00 -7.2301e-01 -3.2357e-01
#   1.0127e+00 -1.1702e+00  1.8223e+00  ...   8.2142e-01 -4.4484e-01  3.1254e-01
#   7.3804e-01 -4.6319e-01  1.4026e-01  ...  -1.3889e+00  6.9481e-01 -2.1855e+00
# [torch.FloatTensor of size 1x235x200]

# %%
Variable(torch.from_numpy(np.stack(df['abstract_tokenize'][100])).unsqueeze(0))
# Out:
# Variable containing:
# ( 0 ,.,.) =
#  -0.6951  0.6775  0.0112  ...   0.3588 -1.0843 -1.9157
#   0.3185 -1.2010 -1.8983  ...  -1.0472 -1.3813  1.3460
#   1.0616  0.0816 -0.0035  ...   0.5260 -0.1613  0.4796
#            ...             ⋱             ...
#  -0.7610 -0.1022  0.9891  ...  -0.0507  0.0101  1.0804
#   0.8129 -0.5254  0.4741  ...   1.4561 -1.5147 -1.1715
#   0.1559 -0.4288  0.7449  ...   0.5813  0.2296  1.4754
# [torch.FloatTensor of size 1x43x200]

# %%
v = Variable(torch.from_numpy(np.stack(vecs[0])).unsqueeze(0))

# %%
v.data.size()
# Out:
# torch.Size([1, 235, 200])

# %%
from sklearn.utils import shuffle

# %%
np.random.randint(0, 100)
# Out:
# 60

# %%
df.append(dfs['some'], ignore_index=True)
# Out:
#              id               wos_id accession_no       issn  issn_int  \
# 0          7424  WOS:000274469400009        554XK  1436-3240   1436324
# 1         10882  WOS:000279040500008        614FJ  0040-1706     40170
# 2         18436  WOS:000290231500005        759HO  0090-5364     90536
# 3         18572  WOS:000274388800009        553TD  0012-9682     12968
# 4         24742  WOS:000280638400002        635EM  1369-7412   1369741
# 5         32712  WOS:000275920200007        573NI  0040-1706     40170
# 6         40209  WOS:000280359400009        631PH  0090-5364     90536
# 7         40939  WOS:000282875200002        663HY  1369-7412   1369741
# 8         50946  WOS:000276508500002        581GB  0012-9682     12968
# 9         58883  WOS:000282402800011        657HC  0090-5364     90536
# 10        59063  WOS:000275510800008        568GQ  0090-5364     90536
# 11        62075  WOS:000280359400017        631PH  0090-5364     90536
# 12        63137  WOS:000276439000014        580HP  1436-3240   1436324
# 13        65772  WOS:000282882700002        663JQ  0012-9682     12968
# 14        66174  WOS:000276498600004        581CL  1436-3240   1436324
# 15        71967  WOS:000277069000010        588KO  0007-1102      7110
# 16        84474  WOS:000276498600006        581CL  1436-3240   1436324
# 17        88090  WOS:000284964500011        689XP  0012-9682     12968
# 19               STATISTICAL METHODS IN MEDICAL RESEARCH     237-270
# 20                                         TECHNOMETRICS     107-123
# 21                                  ANNALS OF STATISTICS   2499-2524
# 22                                          ECONOMETRICA     603-632
# 23     STOCHASTIC ENVIRONMENTAL RESEARCH AND RISK ASS...   1211-1223
# 24     JOURNAL OF THE ROYAL STATISTICAL SOCIETY SERIE...     533-544
# 25     JOURNAL OF THE ROYAL STATISTICAL SOCIETY SERIE...     143-170
# 26                                          ECONOMETRICA   1201-1237
# 27                                          ECONOMETRICA     697-718
# 28     BRITISH JOURNAL OF MATHEMATICAL & STATISTICAL ...     603-626
# 29               STATISTICAL METHODS IN MEDICAL RESEARCH     507-527
# ...                                                  ...         ...
# 22482                                     BIOINFORMATICS     497-503
# 22483                                     BIOINFORMATICS       36-41
# 22484                                     BIOINFORMATICS   3310-3316
# 22485                                     BIOINFORMATICS   2341-2347
# 22486                                     BIOINFORMATICS     979-980
# 22487                                     BIOINFORMATICS   3060-3063
# 22488                            JOURNAL OF INFORMETRICS     173-179
# 22489                                     BIOINFORMATICS     832-833
# 22490                                     SCIENTOMETRICS     365-375
# 22491                                     BIOINFORMATICS   3084-3092
# 22492                                     SCIENTOMETRICS     551-561
# 22493       ADVANCES IN DATA ANALYSIS AND CLASSIFICATION      95-108
# 22494                                     SCIENTOMETRICS     435-449
# 22495                                     BIOINFORMATICS     I21-I29
# 22496                                     BIOINFORMATICS     836-837
# 22497                                     BIOINFORMATICS   3282-3288
# 22498                                     BIOINFORMATICS   2646-2654
# 22499                            JOURNAL OF INFORMETRICS     134-142
# 22500                                     SCIENTOMETRICS     491-514
# 22501                                     SCIENTOMETRICS     201-218
# 22502                                     SCIENTOMETRICS     499-511
# 22503                                     SCIENTOMETRICS     383-395
# 22504                                     SCIENTOMETRICS     407-418
# 22505                                     BIOINFORMATICS   1587-1593
# 22506                                     BIOINFORMATICS   1205-1207
# 22507                                     BIOINFORMATICS   2921-2928
# 22508                                     BIOINFORMATICS     331-337
# 22509                                     BIOINFORMATICS     346-352
# 22510       ADVANCES IN DATA ANALYSIS AND CLASSIFICATION     263-279
# 22511                                     BIOINFORMATICS     780-786
#
#        page_count  has_abstract             wos_id.1  \
# 0              20             1  WOS:000274469400009
# 1              12             1  WOS:000279040500008
# 2              29             1  WOS:000290231500005
# 3              24             1  WOS:000274388800009
# 4              12             1  WOS:000280638400002
# 5              13             1  WOS:000275920200007
# 6              31             1  WOS:000280359400009
# 7              22             1  WOS:000282875200002
# 8              29             1  WOS:000276508500002
# 9              42             1  WOS:000282402800011
# 10             24             1  WOS:000275510800008
# 11             34             1  WOS:000280359400017
# 12             13             1  WOS:000276439000014
# 13             40             1  WOS:000282882700002
# 14              5             1  WOS:000276498600004
# 15             22             1  WOS:000277069000010
# 16             12             1  WOS:000276498600006
# 17             15             1  WOS:000284964500011
# 18             11             1  WOS:000273561400009
# 19             34             1  WOS:000279354100003
# 20             17             1  WOS:000275920200010
# 21             26             1  WOS:000280359400018
# 22             30             1  WOS:000276508500005
# 23             13             1  WOS:000284425400009
# 24             12             1  WOS:000280638400007
# 25             28             1  WOS:000274188400001
# 26             37             1  WOS:000281062000002
# 27             22             1  WOS:000276508500008
# 28             24             1  WOS:000284251100008
# 29             21             1  WOS:000282430300006
# ...           ...           ...                  ...
# 22482           7             1  WOS:000263406000012
# 22483           6             1  WOS:000261996400006
# 22484           7             1  WOS:000272464000015
# 22485           7             1  WOS:000269607700008
# 22486           2             1  WOS:000264651800028
# 22487           4             1  WOS:000272080800003
# 22488           7             1  WOS:000267144200002
# 22489           2             1  WOS:000264189600022
# 22490          11             1  WOS:000265778100011
# 22491           9             1  WOS:000272080800007
# 22492          11             1  WOS:000266914500007
# 22493          14             1  WOS:000284144200002
# 22494          15             1  WOS:000265778100016
# 22495           9             1  WOS:000266498300004
# 22496           2             1  WOS:000264189600024
# 22497           7             1  WOS:000272464000011
# 22498           9             1  WOS:000270685200004
# 22499           9             1  WOS:000264317300004
# 22500          24             1  WOS:000268019900015
# 22501          18             1  WOS:000264487900013
# 22502          13             1  WOS:000270979000014
# 22503          13             1  WOS:000263155900001
# 22504          12             1  WOS:000268019900010
# 22505           7             1  WOS:000267213300002
# 22506           3             1  WOS:000265523300023
# 22507           8             1  WOS:000271564300005
# 22508           7             1  WOS:000262959500007
# 22509           7             1  WOS:000262959500009
# 22510          17             1  WOS:000284145000006
# 22511           7             1  WOS:000264189600012
#
#                                                 abstract  \
# 0      This study aims to model the joint probability...
# 1      Motivated by two industrial experiments in whi...
# 2      We demonstrate that the processes underlying o...
# 3      This paper studies partnerships that employ a ...
# 4      I describe the background for the paper 'Contr...
# 5      Multivariate receptor modeling is used to esti...
# 6      The paper considers nonparametric specificatio...
# 7      Testing the equality of two survival distribut...
# 8      We examine the labor market effects of incompl...
# 9      We present a new adaptive kernel density estim...
# 10     We address the problem of parameter estimation...
# 11     In this paper we consider a novel statistical ...
# 12     Climate projections for the Huaihe River Basin...
# 13     We discuss the identification and estimation o...
# 14     Particulate matter with an aerodynamic equival...
# 15     In personality and attitude measurement, the p...
# 16     Pseudodifferential evolution models have been ...
# 17     Two Ellsberg-style thought experiments are des...
# 18     In this paper, a certain bivariate exponential...
# 19     Complex intervention trials should be able to ...
# 20     A new solution of the general nonparametric k-...
# 21     Deriving optimal designs for nonlinear models ...
# 22     Unlike the prediction of a frictionless open e...
# 23     A data assimilation method is developed to cal...
# 24     Bayesian methods for inference on finite popul...
# 25     We examine philosophical problems and sampling...
# 26     This paper develops a technique for studying i...
# 27     This paper considers model averaging as a way ...
# 28     Marginal maximum-likelihood procedures for par...
# 29     As mammography screening aims to improve the p...
# ...                                                  ...
# 22482  Background: Large-scale candidate-gene and gen...
# 22483  Motivation: High-density DNA microarrays provi...
# 22484  Motivation: The comprehensive information of s...
# 22485  Motivation: High-density oligonucleotide tilin...
# 22486  A variety of specialist databases have been de...
# 22487  Motivation: A key element in understanding the...
# 22488  While ISSI was founded in 1993, Scientometrics...
# 22489  Motivation: With the increasing use of post-ge...
# 22490  A case study of an emerging research area is p...
# 22491  Motivation: Accurate genome annotation or prot...
# 22492  This paper briefly reviews the knowledge-gener...
# 22493  In this paper, we compare the accuracy of four...
# 22494  Although many studies have analyzed the "synch...
# 22495  Motivation: Genome-wide association studies ar...
# 22496  The Biochemical Simulation Environment (BISEN)...
# 22497  Motivation: All metabolic networks contain met...
# 22498  Motivation: The RNA-RNA interaction problem (R...
# 22499  In this communication we perform an analysis o...
# 22500  The bibliometric indices of the scientific fie...
# 22501  The possibilities of the Response Surface Meth...
# 22502  Although there are many measures of centrality...
# 22503  We set out to analyse and quantify the papers ...
# 22504  This study analyses the bibliometric character...
# 22505  Motivation: The most accurate way to determine...
# 22506  The analysis of gene regulatory networks (GRNs...
# 22507  Protein structures can be viewed as networks o...
# 22508  Motivation: Feature selection approaches have ...
# 22509  Motivation: Currently the confocal scanning mi...
# 22510  The forward search is a powerful general metho...
# 22511  Motivation: In recent years, the biological li...
#
#                                           title_tokenize  \
# 0      [[0.0236096, 0.0032635, -0.0518586, -0.121607,...
# 1      [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 2      [[-1.0149, 0.822729, 0.662489, -1.04985, 0.319...
# 3      [[0.750476, 0.41266, 0.283005, -0.132385, -0.4...
# 4      [[0.406431, -1.19213, -0.848863, -0.782029, 0....
# 5      [[0.16723, -1.33395, -1.38288, -0.0678202, 0.1...
# 6      [[-0.18386, -1.14652, 0.134341, 0.534507, 1.11...
# 7      [[0.666772, -0.210443, -0.0184195, 0.323417, 0...
# 8      [[2.26076, 0.179787, 1.55793, 1.42612, 0.05444...
# 9      [[-0.246178, 0.639709, 0.395433, 0.421159, -0....
# 10     [[0.174027, -0.30981, 0.884471, -0.645013, -0....
# 11     [[0.124852, 0.12872, 0.0402332, 0.0544731, 0.0...
# 12     [[-0.483508, 0.0879628, -0.584125, 0.393956, -...
# 13     [[1.29989, -1.77982, 0.0816418, -1.34734, 0.29...
# 14     [[1.05752, -0.585406, 0.0753302, -1.20323, 0.0...
# 15     [[0.12848, 0.00174056, 0.102357, -0.0408469, -...
# 16     [[-0.105941, -0.690518, -0.155211, -0.376872, ...
# 17     [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 18     [[-0.721739, -1.18704, 0.775862, -0.409899, -0...
# 19     [[0.519019, 0.257642, 0.0586209, -0.409734, -0...
# 20     [[0.469151, 0.130577, -1.0355, -0.445105, 1.10...
# 21     [[-2.1545, 0.655978, -0.658545, -1.0207, 0.871...
# 22     [[0.129938, 0.473202, -0.027714, 0.531481, -0....
# 23     [[-0.802658, -0.0493962, -0.0566216, -0.063998...
# 24     [[1.92527, -0.89972, -0.30324, 0.532389, 0.520...
# 25     [[-2.1545, 0.655978, -0.658545, -1.0207, 0.871...
# 26     [[-0.147509, 0.662106, 0.0685406, -0.669085, 0...
# 27     [[-0.251308, -0.979181, -1.01234, -0.171423, 0...
# 28     [[-0.721636, 0.702152, -0.57156, 0.428566, 0.9...
# 29     [[0.690233, -0.660109, -0.146449, 0.75428, 0.2...
# ...                                                  ...
# 22482  [[-0.415349, 0.129502, 0.207354, -0.567649, 0....
# 22483  [[1.91649, -1.70725, -0.100994, -0.0511036, 0....
# 22484  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22485  [[1.67836, -1.04155, -0.787499, -0.794694, 0.3...
# 22486  [[0.303418, -0.475912, -0.113195, 0.0425318, 0...
# 22487  [[0.149391, -1.11385, 0.176902, -0.865956, -0....
# 22488  [[-0.968285, -1.80582, 0.681413, -1.58691, -0....
# 22489  [[0.0178083, -0.010803, -0.00876227, -0.002604...
# 22490  [[-0.845816, 2.54986, 0.142379, 0.0178994, 0.2...
# 22491  [[0.0689826, -0.240573, -1.01455, 0.490886, 0....
# 22492  [[0.375594, -1.24115, 1.89088, -0.794791, -1.0...
# 22493  [[-0.130643, -0.339524, 1.05822, -0.841078, -0...
# 22494  [[2.26076, 0.179787, 1.55793, 1.42612, 0.05444...
# 22495  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22496  [[0.044507, 0.0193625, 0.0221353, 0.0257063, -...
# 22497  [[1.71302, -0.564498, 0.693292, 1.1238, 0.7196...
# 22498  [[-0.511215, -0.579523, -0.29671, -0.0859848, ...
# 22499  [[0.373921, 0.505442, 0.480416, -0.0501929, -0...
# 22500  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22501  [[0.139779, -0.0459955, -0.799931, -0.717649, ...
# 22502  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22503  [[0.149391, -1.11385, 0.176902, -0.865956, -0....
# 22504  [[0.184197, -0.0610672, 0.913702, -0.161063, 0...
# 22505  [[-0.0688287, -0.199489, -0.0358555, -0.041141...
# 22506  [[0.0458521, 0.0480014, -0.038336, -0.0138941,...
# 22507  [[0.738242, -2.32816, 1.3854, -2.97112, -1.002...
# 22508  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22509  [[0.323591, -0.800678, 1.57945, -0.356535, 0.6...
# 22510  [[0.861443, -0.628971, -0.95246, -0.0284146, 1...
# 22511  [[-0.394392, 0.0341547, -0.177602, 0.0733263, ...
#
#                                        abstract_tokenize
# 0      [[2.77366, 0.652774, -0.440765, 0.29811, 0.181...
# 1      [[1.11575, 0.482034, -0.0183253, -0.291243, 0....
# 2      [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 3      [[2.77366, 0.652774, -0.440765, 0.29811, 0.181...
# 4      [[0.624336, 0.337605, 0.939134, 0.760823, -0.7...
# 5      [[0.950022, 0.07348, -0.855757, 0.17769, 0.601...
# 6      [[1.06158, 0.0815509, -0.0035336, 0.283464, -0...
# 7      [[0.0917527, 0.151416, -0.58268, -1.28097, -1....
# 8      [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 9      [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 10     [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 11     [[0.143027, -0.599736, -0.0588015, -0.86085, -...
# 12     [[-1.87017, 1.31359, -0.175132, -1.07863, -1.3...
# 13     [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 14     [[-0.629298, -0.194363, 0.830123, -0.376948, -...
# 15     [[0.143027, -0.599736, -0.0588015, -0.86085, -...
# 16     [[0.050274, 0.133205, -0.0966964, 0.064967, -0...
# 17     [[-1.18478, -0.779278, -1.39955, -0.414427, -0...
# 18     [[0.143027, -0.599736, -0.0588015, -0.86085, -...
# 19     [[-0.157663, -0.408969, -0.970429, -1.13978, -...
# 20     [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 21     [[0.232491, -0.863532, -0.338407, -0.127882, 0...
# 22     [[-0.254652, -1.37322, -1.34665, 1.1651, 0.781...
# 23     [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 24     [[1.92527, -0.89972, -0.30324, 0.532389, 0.520...
# 25     [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 26     [[2.77366, 0.652774, -0.440765, 0.29811, 0.181...
# 27     [[2.77366, 0.652774, -0.440765, 0.29811, 0.181...
# 28     [[-0.721636, 0.702152, -0.57156, 0.428566, 0.9...
# 29     [[-0.662784, -0.965487, -0.592402, -0.48063, 0...
# ...                                                  ...
# 22482  [[0.310466, -1.27022, -0.309727, -0.0205326, 0...
# 22483  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22484  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22485  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22486  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22487  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22488  [[0.230952, -1.26073, -0.0609785, 0.672727, 0....
# 22489  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22490  [[1.16123, 1.63286, 0.34318, 0.380847, 0.25513...
# 22491  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22492  [[2.77366, 0.652774, -0.440765, 0.29811, 0.181...
# 22493  [[0.143027, -0.599736, -0.0588015, -0.86085, -...
# 22494  [[0.178144, -0.762334, -0.931472, -0.0632883, ...
# 22495  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22496  [[1.06158, 0.0815509, -0.0035336, 0.283464, -0...
# 22497  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22498  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22499  [[0.143027, -0.599736, -0.0588015, -0.86085, -...
# 22500  [[1.06158, 0.0815509, -0.0035336, 0.283464, -0...
# 22501  [[1.06158, 0.0815509, -0.0035336, 0.283464, -0...
# 22502  [[0.178144, -0.762334, -0.931472, -0.0632883, ...
# 22503  [[-0.695066, 0.677472, 0.0111698, 0.209141, -0...
# 22504  [[2.77366, 0.652774, -0.440765, 0.29811, 0.181...
# 22505  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22506  [[1.06158, 0.0815509, -0.0035336, 0.283464, -0...
# 22507  [[1.73469, 0.495102, 0.260356, 0.247769, 0.521...
# 22508  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22509  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
# 22510  [[1.06158, 0.0815509, -0.0035336, 0.283464, -0...
# 22511  [[1.09366, -0.162372, -0.954114, -1.32275, 0.2...
#
# [22512 rows x 25 columns]

# %%
rnn2(v)
# Out:
# Variable containing:
# 1.00000e-02 *
#   6.0034 -3.0117
# [torch.FloatTensor of size 1x2]

# %%
rnn2 = BiRNN(200, hidden_size, num_layers)

# %%
rnn = BiRNN(input_size, hidden_size, num_layers)
rnn
# Out:
# BiRNN (
#   (lstm): LSTM(28, 128, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear (256 -> 2)
# )

# %%
vecs = sorted(df['abstract_tokenize'][:10], key=lambda x: len(x), reverse=True)
maxlen = max(len(v) for v in vecs)
result = np.zeros((len(vecs), maxlen, 200))
lens = []
for i, v in enumerate(vecs):
    unpad = np.stack(v)
    lens.append(unpad.shape[0])
    #print(unpad.shape)
    result[i, :unpad.shape[0],:unpad.shape[1]] = unpad

# %%
retT = Variable(torch.from_numpy(result))

# %%
#retT

# %%
padded = torch.nn.utils.rnn.pack_padded_sequence(retT, lens, batch_first=True)

# %%
#rnn(padded)

# %%
np.pad(np.stack(vecs[0]), (200, 300), 'constant').shape
# Out:
# (695, 700)

# %%
result = np.zeros((maxlen, 200))
unpad = np.stack(vecs[0])

# %%
result[:unpad.shape[0],:unpad.shape[1]] = unpad

# %%
result.shape
# Out:
# (10, 235, 200)

# %%
torch.nn.functional.pad(ten, 300)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-31-4c84bc8a3cac> in <module>()
# ----> 1 torch.nn.functional.pad(ten, 300)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/functional.py in pad(input, pad, mode, value)
#     662             return _functions.thnn.ReplicationPad3d(*pad)(input)
#     663     else:
# --> 664         raise NotImplementedError("Only 4D and 5D padding is supported for now")
#     665
#     666
#
# NotImplementedError: Only 4D and 5D padding is supported for now

# %%
t = torch.zeros(10, maxlen, 200)

# %%
for i, v in enumerate(vecs):
    t[i] += torch.from_numpy(np.stack(v))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-1bd90b8c7fa4> in <module>()
#       1 for i, v in enumerate(vecs):
# ----> 2     t[i] += torch.from_numpy(np.stack(v))
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/tensor.py in __iadd__(self, other)
#     269
#     270     def __iadd__(self, other):
# --> 271         return self.add_(other)
#     272
#     273     def __sub__(self, other):
#
# RuntimeError: inconsistent tensor size at /Users/Reid/Desktop/pytorch/torch/lib/TH/generic/THTensorMath.c:831

# %%
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable


# Hyper Parameters
sequence_length = 28
input_size = 28
hidden_size = 128
num_layers = 2
num_classes = 10
batch_size = 100
num_epochs = 2
learning_rate = 0.003

# MNIST Dataset
train_dataset = dsets.MNIST(root='./data/',
                            train=True, 
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root='./data/',
                           train=False, 
                           transform=transforms.ToTensor())

# %%
t = train_loader.__iter__().__next__()

# %%
#t[0].view(-1, sequence_length, input_size)

# %%
# Data Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
import numpy as np
import torch.nn
import torch.nn.functional


import torch
import torch.nn as nn
#import torchvision.datasets as dsets
#import torchvision.transforms as transforms
from torch.autograd import Variable

class BiRNN(nn.Module):
    #Mostly from pytorch example
    def __init__(self, input_size, hidden_size, num_layers):
        super(BiRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 2)  # 2 for bidirection

    def forward(self, x):
        # Set initial states
        h0 = Variable(torch.zeros(self.num_layers*2, x.size(0), self.hidden_size)) # 2 for bidirection
        c0 = Variable(torch.zeros(self.num_layers*2, x.size(0), self.hidden_size))

        # Forward propagate RNN
        out, _ = self.lstm(x, (h0, c0))

        # Decode hidden state of last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
rnn = BiRNN(input_size, hidden_size, num_layers)

# %%
var = Variable(t[0].view(-1, sequence_length, input_size))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-54-3087d127e813> in <module>()
# ----> 1 var = Variable(t[0].view(-1, sequence_length + 1, input_size))
#
# RuntimeError: size '[-1 x 29 x 28]' is invalid for input of with 78400 elements at /Users/Reid/Desktop/pytorch/torch/lib/TH/THStorage.c:55

# %%
df = dfs['']
# Out:
# Variable containing:
# 1.00000e-02 *
#  -4.8613  2.9809
#  -4.6015  3.0765
#  -4.5531  3.0600
#  -4.7129  2.9618
#  -4.9513  3.1830
#  -4.4397  3.0848
#  -4.5265  3.0862
#  -4.5155  3.0755
#  -4.5753  3.0152
#  -4.6473  3.2008
#  -4.4394  3.0768
#  -4.5466  3.0591
#  -4.3964  3.1822
#  -4.4455  3.0576
#  -4.4507  2.6725
#  -4.6340  3.0555
#  -4.6107  3.0134
#  -4.3867  3.1557
#  -4.5146  3.0258
#  -4.3053  3.0793
#  -4.4365  3.1178
#  -4.5079  2.9617
#  -4.4378  2.9990
#  -4.4171  3.0907
#  -4.3732  3.1572
#  -4.6967  3.0112
#  -4.5943  3.1336
#  -4.5344  2.8000
#  -4.6115  3.0256
#  -4.7264  3.0784
#  -4.5196  3.1054
#  -4.2958  3.1021
#  -4.2825  3.1628
#  -4.5096  3.1085
#  -4.3982  3.0940
#  -4.5625  3.1059
#  -4.8034  3.0256
#  -4.5028  3.0618
#  -4.3602  3.0877
#  -4.3708  3.0836
#  -4.5198  2.9863
#  -4.6345  3.0136
#  -4.5054  3.0775
#  -4.5420  3.0830
#  -4.5252  3.0393
#  -4.5971  3.1681
#  -4.3901  3.0506
#  -4.3719  3.0904
#  -4.5617  3.0351
#  -4.3903  3.0761
#  -4.3854  3.1220
#  -4.4411  3.0520
#  -4.6094  3.0832
#  -4.6056  3.0931
#  -4.6074  3.2343
#  -4.4951  3.0924
#  -4.7021  2.9837
#  -4.6577  3.2357
#  -4.4187  3.1214
#  -4.5800  3.0402
#  -4.5054  3.0484
#  -5.0111  3.1428
#  -4.6432  3.0591
#  -5.1168  3.3928
#  -4.6008  3.0632
#  -4.6098  2.9548
#  -4.5593  3.0459
#  -4.8783  3.0388
#  -4.7793  3.0240
#  -4.3436  3.0820
#  -4.6062  3.0732
#  -4.1993  3.0596
#  -4.7274  3.0150
#  -4.4696  3.0396
#  -4.5250  3.1439
#  -4.7042  3.1871
#  -4.5917  3.0541
#  -4.4722  3.0805
#  -4.8388  3.1435
#  -4.6463  3.0914
#  -4.3208  3.1351
#  -4.5648  3.1170
#  -4.5668  3.0751
#  -4.5807  2.9628
#  -4.5302  3.1331
#  -4.9032  3.0724
#  -4.4328  3.1404
#  -4.6771  3.0490
#  -4.5530  3.0767
#  -4.3767  3.1134
#  -4.5965  3.1523
#  -4.5833  3.0011
#  -4.4689  3.0218
#  -4.4574  2.8146
#  -4.5403  3.0481
#  -4.6378  3.1865
#  -5.0804  3.1195
#  -4.4998  3.1018
#  -4.5083  3.0657
#  -4.4902  3.1021
# [torch.FloatTensor of size 100x2]

# %%
vec = np.stack(df['abstract_tokenize'][0])

# %%
var = torch.from_numpy(vec)

# %%
var = Variable(var)

# %%
RNN(var)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-53ff167d6ff2> in <module>()
# ----> 1 RNN(var)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# <ipython-input-25-dade8b1b6831> in forward(self, x)
#      26
#      27         # Forward propagate RNN
# ---> 28         out, _ = self.lstm(x, (h0, c0))
#      29
#      30         # Decode hidden state of last time step
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#      89             dropout_state=self.dropout_state
#      90         )
# ---> 91         output, hidden = func(input, self.all_weights, hx)
#      92         if is_packed:
#      93             output = PackedSequence(output, batch_sizes)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     341         else:
#     342             func = AutogradRNN(*args, **kwargs)
# --> 343         return func(input, *fargs, **fkwargs)
#     344
#     345     return forward
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hidden)
#     241             input = input.transpose(0, 1)
#     242
# --> 243         nexth, output = func(input, hidden, weight)
#     244
#     245         if batch_first and batch_sizes is None:
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight)
#      81                 l = i * num_directions + j
#      82
# ---> 83                 hy, output = inner(input, hidden[l], weight[l])
#      84                 next_hidden.append(hy)
#      85                 all_output.append(output)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight)
#     110         steps = range(input.size(0) - 1, -1, -1) if reverse else range(input.size(0))
#     111         for i in steps:
# --> 112             hidden = inner(input[i], hidden, *weight)
#     113             # hack to handle LSTM
#     114             output.append(hidden[0] if isinstance(hidden, tuple) else hidden)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in LSTMCell(input, hidden, w_ih, w_hh, b_ih, b_hh)
#      28
#      29     hx, cx = hidden
# ---> 30     gates = F.linear(input, w_ih, b_ih) + F.linear(hx, w_hh, b_hh)
#      31
#      32     ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     451         return _functions.linear.Linear.apply(input, weight)
#     452     else:
# --> 453         return _functions.linear.Linear.apply(input, weight, bias)
#     454
#     455
#
# /Users/Reid/anaconda/lib/python3.6/site-packages/torch/nn/_functions/linear.py in forward(ctx, input, weight, bias)
#      10         ctx.save_for_backward(input, weight, bias)
#      11         output = input.new(input.size(0), weight.size(0))
# ---> 12         output.addmm_(0, 1, input, weight.t())
#      13         if bias is not None:
#      14             output.add_(bias.expand_as(output))
#
# RuntimeError: matrices expected, got 1D, 2D tensors at /Users/Reid/Desktop/pytorch/torch/lib/TH/generic/THTensorMath.c:1232

# %%
df['abstract'][0]
# Out:
# "This study aims to model the joint probability distribution of periodic hydrologic data using meta-elliptical copulas. Monthly precipitation data from a gauging station (410120) in Texas, US, was used to illustrate parameter estimation and goodness-of-fit for univariate drought distributions using chi-square test, Kolmogorov-Smirnov test, Cramer-von Mises statistic, Anderson-Darling statistic, modified weighted Watson statistic, and Liao and Shimokawa statistic. Pearson's classical correlation coefficient r (n) , Spearman's rho (n), Kendall's tau, Chi-Plots, and K-Plots were employed to assess the dependence of drought variables. Several meta-elliptical copulas and Gumbel-Hougaard, Ali-Mikhail-Haq, Frank and Clayton copulas were tested to determine the best-fit copula. Based on the root mean square error and the Akaike information criterion, meta-Gaussian and t copulas gave a better fit. A bootstrap version based on Rosenblatt's transformation was employed to test the goodness-of-fit for meta-Gaussian and t copulas. It was found that none of meta-Gaussian and t copulas considered could be rejected at the given significance level. The meta-Gaussian copula was employed to model the dependence, and these results were found satisfactory."

# %%
dfLittle = pandas.read_csv('data/little.tsv', sep='\t')
dfSome = pandas.read_csv('data/some.tsv', sep='\t')
dfMost = pandas.read_csv('data/mostly.tsv', sep='\t')

# %%
def tokenizer(target):
    return nltk.word_tokenize(target.lower())

# %%
def sentinizer(sent):
    try:
        return [s.split() for s in nltk.sent_tokenize(sent.lower())]
    except:
        print(sent)
        raise

# %%
def getVocab(df):
    vocabTitles = list(df['title'].apply(lambda x: x.lower().split()))
    vocabAbs = df['abstract'].apply(sentinizer).sum()
    return vocabTitles + vocabAbs

# %%
vocabTrain = getVocab(dfLittle) + getVocab(dfSome) + getVocab(dfMost)
model = gensim.models.Word2Vec(vocabTrain, size=200, window=5, min_count=1, workers=8)

# %%
nltk.word_tokenize(' the: quick brown')

# %%
gensim.models.Word2Vec.load('temp')

# %%
model.wv['test']

# %%
dfLittle[:10]['abstract'].apply(tokenizer)[0]

# %%
os.makedirs(exist_ok=)

# %%
model.save('temp')

# %%
model.wv['daks:']

# %%
vocabTrain[:1000]

# %%
dfLittle['abstract'].apply(lambda x: nltk.sent_tokenize(x.lower)).sum()

# %%
' '.join(vocabTrain[0])

# %%
[(i, s) for i, s in enumerate(vocabTrain) if len(s) < 1]

# %%
dfMost['abstract']

# %%
model.wv['we']

# %%
#!/usr/local/bin/python3

import metaknowledge as mk
import numpy as np
import pandas
import gensim
import nltk #For POS tagging
import sklearn #For generating some matrices
import pandas #For DataFrames
import numpy as np #For arrays
import matplotlib.pyplot as plt #For plotting
import seaborn #Makes the plots look nice
import IPython.display #For displaying images

import os #For looking through files
import os.path #For managing file paths
import re
import tarfile

mk.VERBOSE_MODE = False

#w2v = gensim.models.word2vec.Word2Vec.load_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary = True)

dataDir = 'data'
outputDir = 'outputs'

outputCSV = 'entries.csv'

targetTags = ['title', 'journal', 'keywords', 'abstract', 'id', 'year']

loadData = True

stop_words_nltk = nltk.corpus.stopwords.words('english')
snowball = nltk.stem.snowball.SnowballStemmer('english')

def normalizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None, vocab = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)

    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)

    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)

    #We will return a list with the stopwords removed
    if vocab is not None:
        vocab_str = '|'.join(vocab)
        workingIter = (w for w in workingIter if re.match(vocab_str, w))

    return list(workingIter)

def trainTestSplit(df, holdBackFraction = .2):
    df = df.reindex(np.random.permutation(df.index))
    holdBackIndex = int(holdBackFraction * len(df))
    train_data = df[holdBackIndex:].copy()
    test_data = df[:holdBackIndex].copy()

    return train_data, test_data

def generateVecs(df, sents = False):
    df['tokenized_text'] = df['text'].apply(lambda x: nltk.word_tokenize(x))
    df['normalized_text'] = df['tokenized_text'].apply(lambda x: normalizeTokens(x))

    if sents:
        df['tokenized_sents'] = df['text'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
        df['normalized_sents'] = df['tokenized_sents'].apply(lambda x: [normlizeTokens(s, stopwordLst = stop_words_nltk, stemmer = None) for s in x])

    ngCountVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=0.5, min_df=3, stop_words='english', norm='l2')
    newsgroupsVects = ngCountVectorizer.fit_transform([' '.join(l) for l in df['normalized_text']])
    df['vect'] = [np.array(v).flatten() for v in newsgroupsVects.todense()]

    return df

# %%
def main():
    if loadData:
        RC = mk.RecordCollection(dataDir)
        dfDict = {t : [] for t in targetTags}
        for R in RC:
            for t in targetTags:
                dfDict[t].append(R.get(t, None))
        df = pandas.DataFrame(dfDict)
        df.to_csv('{}/{}'.format(outputDir, outputCSV))
    else:
        df = pandas.read_csv('{}/{}'.format(outputDir, outputCSV))
    df['text'] = df['abstract']
    df = generateVecs(df)

if __name__ == '__main__':
    main()

# %%
df = pandas.read_csv('{}/{}'.format(outputDir, outputCSV))
df['text'] = df['abstract']
df = generateVecs(df.dropna().copy())

# %%
df['vect'][0].shape

# %%
df.dropna()
