# %%
#!/usr/local/bin/python3

import metaknowledge as mk
import numpy as np
import pandas
import gensim
import nltk #For POS tagging
import sklearn #For generating some matrices
import pandas #For DataFrames
import numpy as np #For arrays
import matplotlib.pyplot as plt #For plotting
import seaborn #Makes the plots look nice
import IPython.display #For displaying images

import os #For looking through files
import os.path #For managing file paths
import re
import tarfile

mk.VERBOSE_MODE = False

#w2v = gensim.models.word2vec.Word2Vec.load_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary = True)

dataDir = 'data'
outputDir = 'outputs'

outputCSV = 'entries.csv'

targetTags = ['title', 'journal', 'keywords', 'abstract', 'id', 'year']

loadData = True

stop_words_nltk = nltk.corpus.stopwords.words('english')
snowball = nltk.stem.snowball.SnowballStemmer('english')

def normalizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None, vocab = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)

    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)

    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)

    #We will return a list with the stopwords removed
    if vocab is not None:
        vocab_str = '|'.join(vocab)
        workingIter = (w for w in workingIter if re.match(vocab_str, w))

    return list(workingIter)

def trainTestSplit(df, holdBackFraction = .2):
    df = df.reindex(np.random.permutation(df.index))
    holdBackIndex = int(holdBackFraction * len(df))
    train_data = df[holdBackIndex:].copy()
    test_data = df[:holdBackIndex].copy()

    return train_data, test_data

def generateVecs(df, sents = False):
    df['tokenized_text'] = df['text'].apply(lambda x: nltk.word_tokenize(x))
    df['normalized_text'] = df['tokenized_text'].apply(lambda x: normalizeTokens(x))

    if sents:
        df['tokenized_sents'] = df['text'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
        df['normalized_sents'] = df['tokenized_sents'].apply(lambda x: [normlizeTokens(s, stopwordLst = stop_words_nltk, stemmer = None) for s in x])

    ngCountVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=0.5, min_df=3, stop_words='english', norm='l2')
    newsgroupsVects = ngCountVectorizer.fit_transform([' '.join(l) for l in df['normalized_text']])
    df['vect'] = [np.array(v).flatten() for v in newsgroupsVects.todense()]

    return df

# %%
def main():
    if loadData:
        RC = mk.RecordCollection(dataDir)
        dfDict = {t : [] for t in targetTags}
        for R in RC:
            for t in targetTags:
                dfDict[t].append(R.get(t, None))
        df = pandas.DataFrame(dfDict)
        df.to_csv('{}/{}'.format(outputDir, outputCSV))
    else:
        df = pandas.read_csv('{}/{}'.format(outputDir, outputCSV))
    df['text'] = df['abstract']
    df = generateVecs(df)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3556f2c1c1ba> in <module>()
#      15
#      16 if __name__ == '__main__':
# ---> 17     main()
#
# <ipython-input-4-3556f2c1c1ba> in main()
#      12         df = pandas.read_csv('{}/{}'.format(outputDir, outputCSV))
#      13     df['text'] = df['abstract']
# ---> 14     df = generateVecs(df)
#      15
#      16 if __name__ == '__main__':
#
# <ipython-input-3-f231dafc109e> in generateVecs(df, sents)
#      68
#      69 def generateVecs(df, sents = False):
# ---> 70     df['tokenized_text'] = df['text'].apply(lambda x: nltk.word_tokenize(x))
#      71     df['normalized_text'] = df['tokenized_text'].apply(lambda x: normalizeTokens(x))
#      72
#
# /usr/local/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
#    2293                 values = self.asobject
# -> 2294                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2295
#    2296         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:66124)()
#
# <ipython-input-3-f231dafc109e> in <lambda>(x)
#      68
#      69 def generateVecs(df, sents = False):
# ---> 70     df['tokenized_text'] = df['text'].apply(lambda x: nltk.word_tokenize(x))
#      71     df['normalized_text'] = df['tokenized_text'].apply(lambda x: normalizeTokens(x))
#      72
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     return [token for sent in sent_tokenize(text, language)
#     107             for token in _treebank_word_tokenize(sent)]
#     108
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      89     """
#      90     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 91     return tokenizer.tokenize(text)
#      92
#      93 # Standard word tokenizer.
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /usr/local/lib/python3.5/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1276     def _slices_from_text(self, text):
#    1277         last_break = 0
# -> 1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
#    1280             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object

# %%
df = pandas.read_csv('{}/{}'.format(outputDir, outputCSV))
df['text'] = df['abstract']
df = generateVecs(df.dropna().copy())

# %%
df['vect'][0].shape
# Out:
# (3831,)

# %%
df.dropna()
# Out:
#       Unnamed: 0                                           abstract  \
# 0              0  We consider discrete-time observations of a co...
# 1              1  Many statistical analyses (e. g., in econometr...
# 2              2  It has been recently shown that, under the mar...
# 3              3  Reference analysis produces objective Bayesian...
# 4              4  We introduce the C++ application and R package...
# 5              5  We introduce a pathwise algorithm for the Cox ...
# 6              6  Semisupervised methods are techniques for usin...
# 7              7  This paper describes the core features of the ...
# 8              8  Matrix completion and quantum tomography are t...
# 9              9  In a multiple testing problem where one is wil...
# 11            11  Response-adaptive randomization hits recently ...
# 12            12  Covariance matrix plays a central role in mult...
# 13            13  The notion of probability density for a random...
# 14            14  This paper illustrates asymptotic properties f...
# 15            15  We aim at estimating a function lambda : [0, 1...
# 16            16  The generalized estimating equations (GEE) met...
# 17            17  We present a minimax optimal solution to the p...
# 18            18  Community detection is one of the fundamental ...
# 19            19  The problem of ranking/ordering instances, ins...
# 24            24  Kernel smoothing is one of the most widely use...
# 25            25  There has been much recent interest in Bayesia...
# 26            26  In many contexts such as queuing theory, spati...
# 27            27  This paper presents a new method for spatially...
# 28            28  Interval censored outcomes arise when a silent...
# 30            30  The estimation of kernel-smoothed relative ris...
# 31            31  We derive multiscale statistics for deconvolut...
# 32            32  Finite mixtures of von Mises-Fisher distributi...
# 33            33  The survPresmooth package for R implements non...
# 34            34  A group-sequential clinical trial design is on...
# 35            35  The aim of this paper is to demonstrate the R ...
# ...          ...                                                ...
# 2173        2173  We investigate structure for pairs of randomiz...
# 2174        2174  We develop fast algorithms for estimation of g...
# 2176        2176  Lack-of-fit testing of a regression model with...
# 2177        2177  The solaR package allows for reproducible rese...
# 2178        2178  Asymptotic equivalence theory developed in the...
# 2180        2180  Maximum likelihood estimation of a log-concave...
# 2182        2182  This article considers estimation of constant ...
# 2183        2183  Recently, new nonparametric multivariate exten...
# 2184        2184  We consider two alternative tests to the Highe...
# 2185        2185  There is a lack of robust statistical analyses...
# 2186        2186  Hierarchical Bayesian modeling of large point-...
# 2187        2187  Nonlinear regression models are applied in a b...
# 2188        2188  We study the asymptotic behavior of the Maximu...
# 2190        2190  This paper studies the sparsistency and rates ...
# 2191        2191  Strong consistency and asymptotic normality of...
# 2192        2192  In this paper we study the aggregation problem...
# 2193        2193  Data frames are integral to R. They provide a ...
# 2195        2195  Detecting and measuring lag-dependencies is ve...
# 2196        2196  penalized is a flexible, extensible, and effic...
# 2197        2197  R users can often solve optimization tasks eas...
# 2200        2200  This document provides a brief introduction to...
# 2201        2201  We develop a canonical framework for the study...
# 2202        2202  Linear models with fixed effects and many dumm...
# 2203        2203  This paper provides an introduction to a softw...
# 2204        2204  This article describes the R package rdrobust,...
# 2205        2205  Generalized additive models for location, scal...
# 2207        2207  We Study the asymptotic properties of bridge e...
# 2208        2208  We construct the "expected signature matching"...
# 2209        2209  Frailty models are very useful for analysing c...
# 2210        2210  Penalized splines can be viewed as BLUPs in a ...
#
#                        id                          journal  \
# 0     WOS:000291183300004             ANNALS OF STATISTICS
# 1     WOS:000252431400001  JOURNAL OF STATISTICAL SOFTWARE
# 2     WOS:000248987600006             ANNALS OF STATISTICS
# 3     WOS:000265500500013             ANNALS OF STATISTICS
# 4     WOS:000399022900001  JOURNAL OF STATISTICAL SOFTWARE
# 5     WOS:000288204000001  JOURNAL OF STATISTICAL SOFTWARE
# 6     WOS:000320488200013             ANNALS OF STATISTICS
# 7     WOS:000235180600001  JOURNAL OF STATISTICAL SOFTWARE
# 8     WOS:000327746100007             ANNALS OF STATISTICS
# 9     WOS:000253390000013             ANNALS OF STATISTICS
# 11    WOS:000268604900017             ANNALS OF STATISTICS
# 12    WOS:000280359400007             ANNALS OF STATISTICS
# 13    WOS:000275510800020             ANNALS OF STATISTICS
# 14    WOS:000265500500019             ANNALS OF STATISTICS
# 15    WOS:000248692700007             ANNALS OF STATISTICS
# 16    WOS:000334019700001  JOURNAL OF STATISTICAL SOFTWARE
# 17    WOS:000304684900015             ANNALS OF STATISTICS
# 18    WOS:000368022000013             ANNALS OF STATISTICS
# 19    WOS:000254502700013             ANNALS OF STATISTICS
# 24    WOS:000252428800001  JOURNAL OF STATISTICAL SOFTWARE
# 25    WOS:000232927600001  JOURNAL OF STATISTICAL SOFTWARE
# 26    WOS:000247498100015             ANNALS OF STATISTICS
# 27    WOS:000251096100018             ANNALS OF STATISTICS
# 28    WOS:000343788100004                        R JOURNAL
# 30    WOS:000287814900001  JOURNAL OF STATISTICAL SOFTWARE
# 31    WOS:000321847600010             ANNALS OF STATISTICS
# 32    WOS:000341642400001  JOURNAL OF STATISTICAL SOFTWARE
# 33    WOS:000324372200001  JOURNAL OF STATISTICAL SOFTWARE
# 34    WOS:000365976500001  JOURNAL OF STATISTICAL SOFTWARE
# 35    WOS:000341584600001  JOURNAL OF STATISTICAL SOFTWARE
# ...                   ...                              ...
# 2173  WOS:000282402800018             ANNALS OF STATISTICS
# 2174  WOS:000275203200001  JOURNAL OF STATISTICAL SOFTWARE
# 2176  WOS:000263129000005             ANNALS OF STATISTICS
# 2177  WOS:000308909400001  JOURNAL OF STATISTICAL SOFTWARE
# 2178  WOS:000271673500005             ANNALS OF STATISTICS
# 2180  WOS:000282402800013             ANNALS OF STATISTICS
# 2182  WOS:000280359400014             ANNALS OF STATISTICS
# 2183  WOS:000239139800001  JOURNAL OF STATISTICAL SOFTWARE
# 2184  WOS:000330204900005             ANNALS OF STATISTICS
# 2185  WOS:000330193300008                        R JOURNAL
# 2186  WOS:000349846900001  JOURNAL OF STATISTICAL SOFTWARE
# 2187  WOS:000365977800001  JOURNAL OF STATISTICAL SOFTWARE
# 2188  WOS:000253077800014             ANNALS OF STATISTICS
# 2190  WOS:000271673700019             ANNALS OF STATISTICS
# 2191  WOS:000268605000006             ANNALS OF STATISTICS
# 2192  WOS:000263129000020             ANNALS OF STATISTICS
# 2193  WOS:000312289400001  JOURNAL OF STATISTICAL SOFTWARE
# 2195  WOS:000352917500001  JOURNAL OF STATISTICAL SOFTWARE
# 2196  WOS:000389072400001  JOURNAL OF STATISTICAL SOFTWARE
# 2197  WOS:000294231700001  JOURNAL OF STATISTICAL SOFTWARE
# 2200  WOS:000341584400001  JOURNAL OF STATISTICAL SOFTWARE
# 2201  WOS:000372594300012             ANNALS OF STATISTICS
# 2202  WOS:000330193300012                        R JOURNAL
# 2203  WOS:000249734800001  JOURNAL OF STATISTICAL SOFTWARE
# 2204  WOS:000357431900005                        R JOURNAL
# 2205  WOS:000392512300001  JOURNAL OF STATISTICAL SOFTWARE
# 2207  WOS:000254502700004             ANNALS OF STATISTICS
# 2208  WOS:000296995500008             ANNALS OF STATISTICS
# 2209  WOS:000303804000001  JOURNAL OF STATISTICAL SOFTWARE
# 2210  WOS:000232928800001  JOURNAL OF STATISTICAL SOFTWARE
#
#                                                keywords  \
# 0     ['NONPARAMETRIC REGRESSION', 'MICROSTRUCTURE N...
# 1     ['3-STAGE LEAST-SQUARES', 'REGRESSION EQUATION...
# 2      ['RISK BOUNDS', 'CONVERGENCE', 'CLASSIFICATION']
# 3     ['POSTERIOR DISTRIBUTIONS', 'MATHEMATICAL-THEO...
# 4     ['MACHINE LEARNING-METHODS', 'PROBABILITY ESTI...
# 5     ['GENERALIZED LINEAR-MODELS', 'GENE-EXPRESSION...
# 6                                           ['SAMPLES']
# 7     ['LINEAR-MODELS', 'REGRESSION-MODELS', 'INFERE...
# 8     ['LOW-RANK MATRICES', 'HIGH-DIMENSIONAL MATRIC...
# 9     ['FAMILYWISE ERROR RATE', 'FALSE DISCOVERY RAT...
# 11    ['BIASED COIN DESIGNS', 'SEQUENTIAL CLINICAL-T...
# 12                            ['SELECTION', 'SPARSITY']
# 13    ['PRINCIPAL-COMPONENTS-ANALYSIS', 'NONPARAMETR...
# 14    ['BIASED-COIN DESIGNS', 'CLINICAL-TRIALS', 'AL...
# 15    ['ASYMPTOTIC NORMALITY', 'GRENANDER-ESTIMATOR'...
# 16                                       ['EFFICIENCY']
# 17    ['MAXIMUM-LIKELIHOOD-ESTIMATION', 'LOG-CONCAVE...
# 18    ['STOCHASTIC BLOCK-MODELS', 'SOCIAL NETWORKS',...
# 19    ['MOMENT INEQUALITIES', 'RISK MINIMIZATION', '...
# 24    ['CROSS-VALIDATION', 'BANDWIDTH SELECTION', 'M...
# 25                                           ['BINARY']
# 26                                        ['INFERENCE']
# 27         ['VARYING-COEFFICIENT MODELS', 'REGRESSION']
# 28                                         ['TUTORIAL']
# 30                        ['GEOGRAPHICAL EPIDEMIOLOGY']
# 31    ['KERNEL DENSITY ESTIMATORS', 'NONPARAMETRIC D...
# 32    ['MODIFIED BESSEL-FUNCTIONS', 'FUNCTION RATIOS...
# 33    ['RANDOM CENSORSHIP MODELS', 'KAPLAN-MEIER', '...
# 34    ['CLINICAL-TRIALS', 'CONTINUOUS OUTCOMES', 'SP...
# 35    ['CAPTURE-RECAPTURE METHODS', 'MODEL DETERMINA...
# ...                                                 ...
# 2173                  ['DESIGNS', 'VARIANCE', 'MODELS']
# 2174  ['PENALIZED LOGISTIC-REGRESSION', 'VARIABLE SE...
# 2176       ['NONPARAMETRIC REGRESSION', 'IN-VARIABLES']
# 2177    ['DIFFUSE', 'MODEL', 'IRRADIANCE', 'ALGORITHM']
# 2178  ['GAUSSIAN WHITE-NOISE', 'WAVELET SHRINKAGE', ...
# 2180  ['MAXIMUM-LIKELIHOOD-ESTIMATION', 'PROBABILITY...
# 2182  ['DYNAMICS IN-VIVO', 'PARAMETER-ESTIMATION', '...
# 2183                    ['AFFINE', 'LOCATION', 'TESTS']
# 2184             ['CENTRAL LIMIT-THEOREMS', 'MIXTURES']
# 2185                                  ['LINEAR-MODELS']
# 2186                       ['PACKAGE', 'GEOSTATISTICS']
# 2187  ['LISTERIA-MONOCYTOGENES', 'HEART-FAILURE', 'O...
# 2188  ['MAXIMUM-LIKELIHOOD-ESTIMATION', 'POPULATION ...
# 2190  ['NONCONCAVE PENALIZED LIKELIHOOD', 'LONGITUDI...
# 2191  ['ARCH MODELS', 'GARCH PROCESSES', 'CONSISTENC...
# 2192  ['NONPARAMETRIC REGRESSION', 'ORACLE INEQUALIT...
# 2193           ['SPECIES TRAITS', '4TH-CORNER PROBLEM']
# 2195  ['TIME-SERIES', 'P-VALUES', 'AUTODEPENDOGRAM',...
# 2196  ['VARIABLE SELECTION', 'ORACLE PROPERTIES', 'L...
# 2197  ['CONJUGATE-GRADIENT METHOD', 'UNCONSTRAINED O...
# 2200  ['NONPARAMETRIC REGRESSION', 'CROSS-VALIDATION...
# 2201  ['MAXIMUM-LIKELIHOOD-ESTIMATION', 'GAUSSIAN RA...
# 2202  ['ALTERNATING PROJECTIONS', 'CONVERGENCE', 'DE...
# 2203  ['BOXCAR DECONVOLUTION', 'INVERSE PROBLEMS', '...
# 2204                                     ['ESTIMATORS']
# 2205  ['CHILD GROWTH STANDARDS', 'BOOSTING ALGORITHM...
# 2207  ['NONCONCAVE PENALIZED LIKELIHOOD', '2-WAY SEM...
# 2208              ['STOCHASTIC CALCULUS', 'DIFFUSIONS']
# 2209  ['PROPORTIONAL HAZARDS MODEL', 'HETEROGENEITY'...
# 2210                ['LINEAR MIXED MODELS', 'VARIANCE']
#
#                                                   title  year  \
# 0     ASYMPTOTIC EQUIVALENCE FOR INFERENCE ON THE VO...  2011
# 1     systemfit: A package for estimating systems of...  2007
# 2           Fast learning rates for plug-in classifiers  2007
# 3             THE FORMAL DEFINITION OF REFERENCE PRIORS  2009
# 4     ranger: A Fast Implementation of Random Forest...  2017
# 5     Regularization Paths for Cox's Proportional Ha...  2011
# 6            DENSITY-SENSITIVE SEMISUPERVISED INFERENCE  2013
# 7     The R Package geepack for Generalized Estimati...  2006
# 8     ASYMPTOTIC EQUIVALENCE OF QUANTUM STATE TOMOGR...  2013
# 9     Generalizing Simes' test and Hochberg's stepup...  2008
# 11                EFFICIENT RANDOMIZED-ADAPTIVE DESIGNS  2009
# 12    OPTIMAL RATES OF CONVERGENCE FOR COVARIANCE MA...  2010
# 13    DEFINING PROBABILITY DENSITY FOR A DISTRIBUTIO...  2010
# 14    ASYMPTOTICS IN RESPONSE-ADAPTIVE DESIGNS GENER...  2009
# 15    On the L-P-error of monotonicity constrained e...  2007
# 16    Criteria to Select a Working Correlation Struc...  2014
# 17    OPTIMAL RATES OF CONVERGENCE FOR CONVEX SET ES...  2012
# 18    OPTIMIZATION VIA LOW-RANK APPROXIMATION FOR CO...  2016
# 19    Ranking and empirical minimization of U-statis...  2008
# 24    ks: Kernel density estimation and kernel discr...  2007
# 25    BayesX: Analyzing Bayesian structured additive...  2005
# 26                        Stable marked point processes  2007
# 27    Spatial aggregation of local likelihood estima...  2007
# 28    Stratified Weibull Regression Model for Interv...  2014
# 30    sparr: Analyzing Spatial Relative Risk Using F...  2011
# 31    MULTISCALE METHODS FOR SHAPE CONSTRAINTS IN DE...  2013
# 32    movMF: An R Package for Fitting Mixtures of vo...  2014
# 33    survPresmooth: An R Package for Presmoothed Es...  2013
# 34    OptGS: An R Package for Finding Near-Optimal G...  2015
# 35    conting: An R Package for Bayesian Analysis of...  2014
# ...                                                 ...   ...
# 2173  DECOMPOSITION TABLES FOR EXPERIMENTS. II. TWO-...  2010
# 2174  Regularization Paths for Generalized Linear Mo...  2010
# 2176  MINIMUM DISTANCE REGRESSION MODEL CHECKING WIT...  2009
# 2177  solaR: Solar Radiation and Photovoltaic System...  2012
# 2178  ASYMPTOTIC EQUIVALENCE AND ADAPTIVE ESTIMATION...  2009
# 2180                   QUASI-CONCAVE DENSITY ESTIMATION  2010
# 2182  SIEVE ESTIMATION OF CONSTANT AND TIME-VARYING ...  2010
# 2183  SAS/IML macros for a multivariate analysis of ...  2006
# 2184  TESTS ALTERNATIVE TO HIGHER CRITICISM FOR HIGH...  2013
# 2185  rlme: An R Package for Rank-Based Estimation a...  2013
# 2186  sp Timer: Spatio-Temporal Bayesian Modeling Us...  2015
# 2187  A Toolbox for Nonlinear Regression in R: The P...  2015
# 2188  Estimation of a k-monotone density: Limit dist...  2007
# 2190  SPARSISTENCY AND RATES OF CONVERGENCE IN LARGE...  2009
# 2191  ASYMPTOTIC NORMALITY OF THE QUASI-MAXIMUM LIKE...  2009
# 2192   A UNIVERSAL PROCEDURE FOR AGGREGATING ESTIMATORS  2009
# 2193  Multiple-Table Data in R with the multitable P...  2012
# 2195   SDD: An R Package for Serial Dependence Diagrams  2015
# 2196  penalized: A MATLAB Toolbox for Fitting Genera...  2016
# 2197  Unifying Optimization Algorithms to Aid Softwa...  2011
# 2200       Smoothing Spline ANOVA Models: R Package gss  2014
# 2201   AMPLITUDE AND PHASE VARIATION OF POINT PROCESSES  2016
# 2202                    lfe: Linear Group Fixed Effects  2013
# 2203  The WaveD transform in R: Performs fast transl...  2007
# 2204  rdrobust: An R Package for Robust Nonparametri...  2015
# 2205  gamboostLSS: An R Package for Model Building a...  2016
# 2207  Asymptotic properties of bridge estimators in ...  2008
# 2208  PARAMETER ESTIMATION FOR ROUGH DIFFERENTIAL EQ...  2011
# 2209  frailtypack: An R Package for the Analysis of ...  2012
# 2210  Bayesian analysis for penalized spline regress...  2005
#
#                                                    text
# 0     We consider discrete-time observations of a co...
# 1     Many statistical analyses (e. g., in econometr...
# 2     It has been recently shown that, under the mar...
# 3     Reference analysis produces objective Bayesian...
# 4     We introduce the C++ application and R package...
# 5     We introduce a pathwise algorithm for the Cox ...
# 6     Semisupervised methods are techniques for usin...
# 7     This paper describes the core features of the ...
# 8     Matrix completion and quantum tomography are t...
# 9     In a multiple testing problem where one is wil...
# 11    Response-adaptive randomization hits recently ...
# 12    Covariance matrix plays a central role in mult...
# 13    The notion of probability density for a random...
# 14    This paper illustrates asymptotic properties f...
# 15    We aim at estimating a function lambda : [0, 1...
# 16    The generalized estimating equations (GEE) met...
# 17    We present a minimax optimal solution to the p...
# 18    Community detection is one of the fundamental ...
# 19    The problem of ranking/ordering instances, ins...
# 24    Kernel smoothing is one of the most widely use...
# 25    There has been much recent interest in Bayesia...
# 26    In many contexts such as queuing theory, spati...
# 27    This paper presents a new method for spatially...
# 28    Interval censored outcomes arise when a silent...
# 30    The estimation of kernel-smoothed relative ris...
# 31    We derive multiscale statistics for deconvolut...
# 32    Finite mixtures of von Mises-Fisher distributi...
# 33    The survPresmooth package for R implements non...
# 34    A group-sequential clinical trial design is on...
# 35    The aim of this paper is to demonstrate the R ...
# ...                                                 ...
# 2173  We investigate structure for pairs of randomiz...
# 2174  We develop fast algorithms for estimation of g...
# 2176  Lack-of-fit testing of a regression model with...
# 2177  The solaR package allows for reproducible rese...
# 2178  Asymptotic equivalence theory developed in the...
# 2180  Maximum likelihood estimation of a log-concave...
# 2182  This article considers estimation of constant ...
# 2183  Recently, new nonparametric multivariate exten...
# 2184  We consider two alternative tests to the Highe...
# 2185  There is a lack of robust statistical analyses...
# 2186  Hierarchical Bayesian modeling of large point-...
# 2187  Nonlinear regression models are applied in a b...
# 2188  We study the asymptotic behavior of the Maximu...
# 2190  This paper studies the sparsistency and rates ...
# 2191  Strong consistency and asymptotic normality of...
# 2192  In this paper we study the aggregation problem...
# 2193  Data frames are integral to R. They provide a ...
# 2195  Detecting and measuring lag-dependencies is ve...
# 2196  penalized is a flexible, extensible, and effic...
# 2197  R users can often solve optimization tasks eas...
# 2200  This document provides a brief introduction to...
# 2201  We develop a canonical framework for the study...
# 2202  Linear models with fixed effects and many dumm...
# 2203  This paper provides an introduction to a softw...
# 2204  This article describes the R package rdrobust,...
# 2205  Generalized additive models for location, scal...
# 2207  We Study the asymptotic properties of bridge e...
# 2208  We construct the "expected signature matching"...
# 2209  Frailty models are very useful for analysing c...
# 2210  Penalized splines can be viewed as BLUPs in a ...
#
# [1783 rows x 8 columns]
