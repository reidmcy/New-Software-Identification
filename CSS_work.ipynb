# %%
import os

import pandas
import torch
import pickle
import training
import utilities
import numpy as np
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
import nltk
import sklearn.metrics.pairwise

# %%
targetColumns = ['authors', 'title', 'abstract', 'eid', 'file', 'year', 'source title']

# %%
df_raw = pandas.DataFrame()
for i, fname in enumerate(os.listdir('../CSS_TSS/')):
    if fname.endswith('.csv') and not fname.startswith('CSS'):
        df_file = pandas.read_csv('../CSS_TSS/{}'.format(fname))
        df_file.columns = [s.lower() for s in df_file.columns]
        df_file['file'] = i
        df_raw = df_raw.append(df_file, ignore_index=True)

# %%
df_tss = df_raw[targetColumns].copy()
df_tss['class'] = 0

# %%
df_raw = pandas.DataFrame()
for i, fname in enumerate(os.listdir('../CSS_TSS/')):
    if fname.endswith('.csv') and fname.startswith('CSS'):
        df_file = pandas.read_csv('../CSS_TSS/{}'.format(fname))
        df_file.columns = [s.lower() for s in df_file.columns]
        df_file['file'] = i
        df_raw = df_raw.append(df_file, ignore_index=True)
# Out:
# /Users/Reid/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_css = df_raw[df_raw['bitbybit']][df_raw['wos']][targetColumns].copy()
df_css['class'] = 1
# Out:
# /Users/Reid/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
df = df_css.append(df_tss, ignore_index=True)#.dropna()

# %%
df_css = pandas.read_csv('data/WoS_Related_scopus_b (1).csv')
df_css.columns = [s.lower() for s in df_css.columns]
df_css['file'] = 'tss'
df_css = df_css[targetColumns].copy()
df_css['class'] = 1

# %%
df = df_css.append(df_tss, ignore_index=True)#.dropna()

# %%
df.dropna().__len__()
# Out:
# 92020

# %%
df.__len__()
# Out:
# 92020

# %%
df.to_csv('data/combined.csv')

# %%
df = pandas.read_csv('data/combined.csv')

# %%
df_css.dropna().__len__()
# Out:
# 491

# %%
dfY = pandas.read_csv('outputs/withYears.csv', index_col='eid')
dfY['isCSS'] = dfY['weightP'] > dfY['weightN']

# %%
df.index = df['eid']

# %%
df_j = dfY.join(df, lsuffix = '_l')

# %%
df_p[df_p['isCSS'] == False].iloc[2]['title']
# Out:
# 'What to do on Spring Break? The Role of Predicted, on-Line, and Remembered Experience in Future Choice'

# %%
df_p = df_j[df_j['class'] == 1]
df_p[df_p['isCSS'] == False].iloc[2]['abstract']
# Out:
# "When individuals choose future activities on the basis of their past experiences, what guides those choices? The present study compared students' predicted, on-line, and remembered spring-break experiences, as well as the influence of these factors on students' desire to take a similar vacation in the future. Predicted and remembered experiences were both more positive - and, paradoxically, more negative - than on-line experiences. Of key importance, path analyses revealed that remembered experience, but neither on-line nor anticipated experience, directly predicted the desire to repeat the experience. These results suggest that although on-line measures may be superior to retrospective measures for approximating objective experience, retrospective measures may be superior for predicting choice."

# %%
df_n[df_n['isCSS']].iloc[3]['title']
# Out:
# "Making social science work across space and time: A critical reflection on Robert Putnam's making democracy work"

# %%
df_n = df_j[df_j['class'] == 0]
df_n[df_n['isCSS']].iloc[3]['abstract']
# Out:
# "Political scientists are becoming more self-conscious about how they connect quantitative and qualitative data in social science and about the role of systematic country studies in comparative research. As the most striking example of both practices in recent years, Robert Putnam and his collaborators' Making Democracy Work deserves more serious criticism than it has received. While Putnam's original project aimed at a precise goal - studying how a new administrative reform is institutionalized - his ultimate project aimed at nothing less than examining how differently democracy works in different sociopolitical contexts, operationalized cross-sectionally in southern and northern Italy. The sources of these differences he found in the two regions' histories, which led him to employ the quantitative interregional data he had collected for one purpose to support a model of historical development of North and South. This historical reconstruction rests largely on qualitative data; but it also rests on a set of comparative inferences about individual values and community cohesiveness in the two regions that is of questionable historical validity and innocent of structural grounding. This article applauds Putnam's joining qualitative and quantitative data but attacks his reconstruction of Italian history to fit his model of social capital."

# %%
def compareRows(rows, N, useTitle = True, w2v = None):
    fig, axes = plt.subplots(figsize = (20,25),
                             nrows = len(rows) + 1,
                             gridspec_kw = {'height_ratios': [5] * len(rows) + [1]})
    aLst = []
    for i, row in enumerate(rows):
        if 'title_vecs' in row:
            abVec, tiVec, yVec = utilities.varsFromRow(row)
        else:
            abVec, tiVec, yVec = utilities.varsFromRow(row, w2v)
        if useTitle:
            outLSTM, (h_n, c_n) = N.lstmTi(tiVec)
            s = row['title']
        else:
            outLSTM, (h_n, c_n) = N.lstmAb(abVec)
            s = row['abstract']
        out = N(abVec, tiVec)
        probNeg = np.exp(out.data[0][0])
        probPos = np.exp(out.data[0][1])            
        probNeg = probNeg / (probNeg + probPos)
        probPos = probPos / (probNeg + probPos)
        
        a = np.array(outLSTM.data.tolist())
        aLst.append(a[0, -1, :])
        #a = a[:,:100,:]
        df = pandas.DataFrame(a[0, :, :])
        df.index = nltk.word_tokenize(s)[:a.shape[1]]
        seaborn.heatmap(df, ax = axes[i], label='big')
        axes[i].set_title("Article Title: '{}'\n$P_{{negative}} = {:.4f}, P_{{positive}} = {:.4f}$".format(row['title'], probNeg, probPos), fontsize = 20)
        axes[i].set_xticklabels([])
        
    
    dfDiff = pandas.DataFrame(np.stack([aLst[0], np.fabs(aLst[0] - aLst[1]), aLst[1]]))
    dfDiff.index = ['Top', 'Diff', 'Bottom']
    seaborn.heatmap(dfDiff, ax = axes[-1], xticklabels = [i if i in np.linspace(0, len(dfDiff.columns) - 1, num = 10, dtype='int') else '' for i in range(len(dfDiff.columns))])
    axes[-1].set_title('Difference in Final Output Vectors', fontsize = 20)
    
    return fig, axes

# %%
with open("models/BiRNN-2-256-30.pt", 'rb') as f:
    N = torch.load(f)
N.cuda()
# Out:
# BiRNN-2-256-30

# %%
dataDir = 'data'
modelsDir = 'models'

rawFname = 'combined.csv'
manualFname = None

w2vFname = 'word2vec.bin'
pickleFname = 'dfPickles.p'
regenW2V = False
df_w2v, w2v = utilities.preprocesing(dataDir, rawFname, modelsDir, w2vFname, pickleFname)
# Out:
# Loading W2V
# Loading DF

# %%
# Out:
#        Unnamed: 0                                            authors  \
# 0               0  Johnson H.A., Wagner M.M., Hogan W.R., Chapman...
# 1               1                 Bazelli B., Hindle A., Stroulia E.
# 2               2           Boia M., Faltings B., Musat C.-C., Pu P.
# 3               3  Ofek N., Caragea C., Biyani P., Rokach L., Mit...
# 4               4         Costa J., Silva C., Antunes M., Ribeiro B.
# 5               5                            Jungherr A., Jürgens P.
# 6               6                                       Bronstein J.
# 7               7                               Bonsón E., Ratkai M.
# 8               8        Brownstein J.S., Freifeld C.C., Madoff L.C.
# 9               9  Cash S.J., Thelwall M., Peck S.N., Ferrell J.Z...
# 10             10    Corley C.D., Cook D.J., Mikler A.R., Singh K.P.
# 11             11      Palchykov V., Kertész J., Dunbar R., Kaski K.
# 12             12  Humphreys L., Gill P., Krishnamurthy B., Newbu...
# 13             13                                     Otterbacher J.
# 14             14                                          Pelc K.J.
# 15             15          Liu Y., Kang C., Gao S., Xiao Y., Tian Y.
# 16             16    Yu Z., Zhou X., Zhang D., Schiele G., Becker C.
# 17             17                              Li L., Sun M., Liu Z.
# 18             18         Costa J., Silva C., Antunes M., Ribeiro B.
# 19             19  Coletta L.F.S., De Silva N.F.F., Hruschka E.R....
# 20             20              Muhammad A., Wiratunga N., Lothian R.
# 21             21                   Compton R., Jurgens D., Allen D.
# 22             22                 Saito S., Tomioka R., Yamanishi K.
# 23             23                            Ao J., Zhang P., Cao Y.
# 24             24                               Hauger D., Schedl M.
# 25             25                           Zimmer M., Proferes N.J.
# 26             26             Gomez B.T., Hansford T.G., Krause G.A.
# 27             27              Chen L., Weber I., Okulicz-Kozaryn A.
# 28             28                  Kong S., Mei Q., Feng L., Zhao Z.
# 29             29                          Salganik M.J., Watts D.J.
# ...           ...                                                ...
# 20277       20277                                            Kemp S.
# 20278       20278       Ganzach Y., Ellis S., Pazy A., Ricci-Siag T.
# 20279       20279                                        Margolis H.
# 20280       20280                                           Acker F.
# 20281       20281            Aguiar F., Brañas-Garza P., Miller L.M.
# 20282       20282                                  Rozin P., Wolf S.
# 20283       20283                  Karlsson L., Juslin P., Olsson H.
# 20284       20284                               Hausmann D., Läge D.
# 20285       20285                             Glöckner A., Betsch T.
# 20286       20286                                        Rieskamp J.
# 20287       20287                             Newell B.R., Bröder A.
# 20288       20288              Gaissmaier W., Schooler L.J., Mata R.
# 20289       20289  Neace W.P., Michaud S., Bolling L., Deer K., Z...
# 20290       20290               Shahrabani S., Benzion U., Shavit T.
# 20291       20291    Bucciarelli M., Khemlani S., Johnson-Laird P.N.
# 20292       20292                    Dickinson D.L., Drummond S.P.A.
# 20293       20293                 Schwartz A., Goldberg J., Hazen G.
# 20294       20294                               Neuman E., Neuman S.
# 20295       20295                                           Rozin P.
# 20296       20296                           Hanselmann M., Tanner C.
# 20297       20297                           Marcatto F., Ferrante D.
# 20298       20298                                          Hilton D.
# 20299       20299         De Vries M., Holland R.W., Witteman C.L.M.
# 20300       20300  Zeelenberg M., Nelissen R.M.A., Breugelmans S....
# 20301       20301                             Pfister H.-R., Böhm G.
# 20302       20302                 Västfjäll D., Peters E., Slovic P.
# 20303       20303                             Böhm G., Pfister H.-R.
# 20304       20304                                   Böhm G., Brun W.
# 20305       20305                   Twyman M., Harvey N., Harries C.
# 20306       20306                              Price M.C., Norman E.
#
#                                                    title  \
# 0      Analysis of Web access logs for surveillance o...
# 1       On the personality traits of StackOverflow users
# 2      A :) Is worth a thousand words: How people att...
# 3      Improving sentiment analysis in an online canc...
# 4      Defining semantic meta-hashtags for twitter cl...
# 5      Forecasting the pulse: How deviations from reg...
# 6      Like me! Analyzing the 2012 presidential candi...
# 7      A set of metrics to assess stakeholder engagem...
# 8      Digital disease detection - Harnessing the web...
# 9               Adolescent suicide statements on MySpace
# 10     Text and structural data mining of influenza m...
# 11     Close Relationships: A Study of Mobile Communi...
# 12     Historicizing new media: A content analysis of...
# 13     Gender, writing and ranking in review forums: ...
# 14     Googling the WTO: What search-engine data tell...
# 15     Understanding intra-urban trip patterns from t...
# 16     Understanding social relationship evolution by...
# 17     Discriminating gender on Chinese microblog: A ...
# 18            Concept drift awareness in twitter streams
# 19     Combining classification and clustering for tw...
# 20     A Hybrid Sentiment Lexicon for Social Media Mi...
# 21     Geotagging one hundred million Twitter account...
# 22     Early detection of persistent topics in social...
# 23     Estimating the locations of emergency events f...
# 24     Exploring geospatial music listening patterns ...
# 25     A topology of twitter research: Disciplines, m...
# 26     The pepublicans should pray for rain: Weather,...
# 27                   U.S. religious landscape on twitter
# 28     Real-time predicting bursting hashtags on twitter
# 29     Web-based experiments for the study of collect...
# ...                                                  ...
# 20277     Lay attitudes to trade with low-wage countries
# 20278  On the perception and operationalization of ri...
# 20279                       A note on neglect defaulting
# 20280  New findings on unconscious versus conscious t...
# 20281                   Moral distance in dictator games
# 20282  Attachment to land: The case of the land of Is...
# 20283  Exemplar-based inference in multi-attribute de...
# 20284  Sequential evidence accumulation in decision m...
# 20285  Modeling option and strategy choices with conn...
# 20286  The importance of learning when making inferences
# 20287  Cognitive processes, models and metaphors in d...
# 20288  An ecological perspective to cognitive limits:...
# 20289  Frequency formats, probability formats, or pro...
# 20290  WTP and WTA in competitive and non-competitive...
# 20291                  The psychology of moral reasoning
# 20292  The effects of total sleep deprivation on baye...
# 20293  Prospect theory, reference points, and health ...
# 20294  Reference-dependent preferences and loss avers...
# 20295  Hedonic "adaptation": Specific habituation to ...
# 20296  Taboos and conflicts in decision making: Sacre...
# 20297  The Regret and Disappointment Scale: An instru...
# 20298  Emotional tone and argumentation in risk commu...
# 20299  In the winning mood: Affect in the Iowa gambli...
# 20300  On emotion specificity in decision making: Why...
# 20301  The multiplicity of emotions: A framework of e...
# 20302  Affect, risk perception and future optimism af...
# 20303  Anticipated and experienced emotions in enviro...
# 20304  Intuition and affect in risk perception and de...
# 20305  Trust in motives, trust in competence: Separat...
# 20306  Intuitive decisions on the fringes of consciou...
#
#                                                 abstract                 eid  \
# 0      The purpose of this study was to determine whe...  2-s2.0-21644487468
# 1      In the last decade, developers have been incre...  2-s2.0-84891703786
# 2      Emoticons are widely used to express positive ...  2-s2.0-84893608034
# 3      Online Health Communities is a major source fo...  2-s2.0-84881186112
# 4      Given the wide spread of social networks, rese...  2-s2.0-84893505918
# 5      Purpose: The steady increase of data on human ...  2-s2.0-84885442655
# 6      The present study aims to report the findings ...  2-s2.0-84882331984
# 7      Purpose - This study aims to propose a set of ...  2-s2.0-84884852538
# 8                                [No abstract available]  2-s2.0-66149157263
# 9      The use of social networking sites (SNSs) has ...  2-s2.0-84875207236
# 10     Text and structural data mining of web and soc...  2-s2.0-77949738013
# 11     Mobile phone communication as digital service ...  2-s2.0-84875635155
# 12     This paper seeks to historicize Twitter within...  2-s2.0-84878706618
# 13     Online review forums provide consumers with es...  2-s2.0-84877107057
# 14     How does international law affect state behavi...  2-s2.0-84881076858
# 15     Intra-urban human mobility is investigated by ...  2-s2.0-84866937714
# 16     Mobile and pervasive computing technologies en...  2-s2.0-84885895327
# 17     As user attributes are useful for applications...  2-s2.0-84926671480
# 18     Learning in non-stationary environments is not...  2-s2.0-84946687105
# 19     The goal of sentiment analysis is to determine...  2-s2.0-84922572824
# 20     Sentiment lexicon is a crucial resource for op...  2-s2.0-84946555797
# 21     Geographically annotated social media is extre...  2-s2.0-84921749960
# 22     In social networking services (SNSs), persiste...  2-s2.0-84911191606
# 23     Sina Weibo, the most popular microblogging ser...  2-s2.0-84902275420
# 24     Microblogs are a steadily growing, valuable, a...  2-s2.0-84921361807
# 25     Purpose–The purpose of this paper is to engage...  2-s2.0-84923261975
# 26     The relationship between bad weather and lower...  2-s2.0-34547489506
# 27     Religiosity is a powerful force shaping human ...  2-s2.0-84914144288
# 28     A large number of hashtags are generated every...  2-s2.0-84958539489
# 29     Social scientists are often interested in unde...  2-s2.0-77953978384
# ...                                                  ...                 ...
# 20277  Three studies presented scenarios to lay peopl...  2-s2.0-70350180141
# 20278  We compare and critique two measures of risk p...  2-s2.0-70350144914
# 20279  I introduce the notion of "neglect defaulting,...  2-s2.0-70350139741
# 20280  Ninety-eight Australian students participated ...  2-s2.0-59549105568
# 20281  We perform an experimental investigation using...  2-s2.0-65249146373
# 20282  This is a first study on attachment to nationa...  2-s2.0-70350157268
# 20283  Several studies propose that exemplar retrieva...  2-s2.0-57149129800
# 20284  Judgments and decisions under uncertainty are ...  2-s2.0-68049094609
# 20285  We claim that understanding human decisions re...  2-s2.0-49849102657
# 20286  The assumption that people possess a repertoir...  2-s2.0-56449105104
# 20287  Decision research in psychology has traditiona...  2-s2.0-70349176874
# 20288  Contrary to the common belief that more inform...  2-s2.0-56349155831
# 20289  Five experiments addressed a controversy in th...  2-s2.0-70349932309
# 20290  Theoretical equivalence exists among various a...  2-s2.0-70349902442
# 20291  This article presents a theory of reasoning ab...  2-s2.0-70349917831
# 20292  Subjects performed a decision task (Grether, 1...  2-s2.0-65649084127
# 20293  In preventative health decisions, such as the ...  2-s2.0-70349932303
# 20294  This study employs a Discrete Choice Experimen...  2-s2.0-70349907594
# 20295  People live in a world in which they are surro...  2-s2.0-61849135677
# 20296  Previous studies suggest that choices are perc...  2-s2.0-55549108241
# 20297  The present article investigates the effective...  2-s2.0-70349897342
# 20298  In this paper I explore how the evolution of e...  2-s2.0-70349931321
# 20299  The present research aimed to test the role of...  2-s2.0-45849101964
# 20300  We present a motivational account of the impac...  2-s2.0-51849106345
# 20301  A four-fold classification of emotions with re...  2-s2.0-57349121802
# 20302  Environmental events such as natural disasters...  2-s2.0-70349906432
# 20303  Affective forecasting with respect to two envi...  2-s2.0-70349934409
# 20304                            [No abstract available]  2-s2.0-62749168772
# 20305  According to Siegrist, Earle and Gutscher's (2...  2-s2.0-70349895204
# 20306  Decision making research often dichotomises be...  2-s2.0-65649094960
#
#       file  class                                       title_tokens  \
# 0      tss      1  [analysis, of, web, access, logs, for, surveil...
# 1      tss      1  [on, the, personality, traits, of, stackoverfl...
# 2      tss      1  [a, :, ), is, worth, a, thousand, words, :, ho...
# 3      tss      1  [improving, sentiment, analysis, in, an, onlin...
# 4      tss      1  [defining, semantic, meta-hashtags, for, twitt...
# 5      tss      1  [forecasting, the, pulse, :, how, deviations, ...
# 6      tss      1  [like, me, !, analyzing, the, 2012, presidenti...
# 7      tss      1  [a, set, of, metrics, to, assess, stakeholder,...
# 8      tss      1  [digital, disease, detection, -, harnessing, t...
# 9      tss      1     [adolescent, suicide, statements, on, myspace]
# 10     tss      1  [text, and, structural, data, mining, of, infl...
# 11     tss      1  [close, relationships, :, a, study, of, mobile...
# 12     tss      1  [historicizing, new, media, :, a, content, ana...
# 13     tss      1  [gender, ,, writing, and, ranking, in, review,...
# 14     tss      1  [googling, the, wto, :, what, search-engine, d...
# 15     tss      1  [understanding, intra-urban, trip, patterns, f...
# 16     tss      1  [understanding, social, relationship, evolutio...
# 17     tss      1  [discriminating, gender, on, chinese, microblo...
# 18     tss      1  [concept, drift, awareness, in, twitter, streams]
# 19     tss      1  [combining, classification, and, clustering, f...
# 20     tss      1  [a, hybrid, sentiment, lexicon, for, social, m...
# 21     tss      1  [geotagging, one, hundred, million, twitter, a...
# 22     tss      1  [early, detection, of, persistent, topics, in,...
# 23     tss      1  [estimating, the, locations, of, emergency, ev...
# 24     tss      1  [exploring, geospatial, music, listening, patt...
# 25     tss      1  [a, topology, of, twitter, research, :, discip...
# 26     tss      1  [the, pepublicans, should, pray, for, rain, :,...
# 27     tss      1          [u.s., religious, landscape, on, twitter]
# 28     tss      1  [real-time, predicting, bursting, hashtags, on...
# 29     tss      1  [web-based, experiments, for, the, study, of, ...
# ...    ...    ...                                                ...
# 20277   15      0  [lay, attitudes, to, trade, with, low-wage, co...
# 20278   15      0  [on, the, perception, and, operationalization,...
# 20279   15      0                 [a, note, on, neglect, defaulting]
# 20280   15      0  [new, findings, on, unconscious, versus, consc...
# 20281   15      0             [moral, distance, in, dictator, games]
# 20282   15      0  [attachment, to, land, :, the, case, of, the, ...
# 20283   15      0  [exemplar-based, inference, in, multi-attribut...
# 20284   15      0  [sequential, evidence, accumulation, in, decis...
# 20285   15      0  [modeling, option, and, strategy, choices, wit...
# 20286   15      0  [the, importance, of, learning, when, making, ...
# 20287   15      0  [cognitive, processes, ,, models, and, metapho...
# 20288   15      0  [an, ecological, perspective, to, cognitive, l...
# 20289   15      0  [frequency, formats, ,, probability, formats, ...
# 20290   15      0  [wtp, and, wta, in, competitive, and, non-comp...
# 20291   15      0            [the, psychology, of, moral, reasoning]
# 20292   15      0  [the, effects, of, total, sleep, deprivation, ...
# 20293   15      0  [prospect, theory, ,, reference, points, ,, an...
# 20294   15      0  [reference-dependent, preferences, and, loss, ...
# 20295   15      0  [hedonic, ``, adaptation, '', :, specific, hab...
# 20296   15      0  [taboos, and, conflicts, in, decision, making,...
# 20297   15      0  [the, regret, and, disappointment, scale, :, a...
# 20298   15      0  [emotional, tone, and, argumentation, in, risk...
# 20299   15      0  [in, the, winning, mood, :, affect, in, the, i...
# 20300   15      0  [on, emotion, specificity, in, decision, makin...
# 20301   15      0  [the, multiplicity, of, emotions, :, a, framew...
# 20302   15      0  [affect, ,, risk, perception, and, future, opt...
# 20303   15      0  [anticipated, and, experienced, emotions, in, ...
# 20304   15      0  [intuition, and, affect, in, risk, perception,...
# 20305   15      0  [trust, in, motives, ,, trust, in, competence,...
# 20306   15      0  [intuitive, decisions, on, the, fringes, of, c...
#
#                                          abstract_tokens
# 0      [[the, purpose, of, this, study, was, to, dete...
# 1      [[in, the, last, decade, ,, developers, have, ...
# 2      [[emoticons, are, widely, used, to, express, p...
# 3      [[online, health, communities, is, a, major, s...
# 4      [[given, the, wide, spread, of, social, networ...
# 5      [[purpose, :, the, steady, increase, of, data,...
# 6      [[the, present, study, aims, to, report, the, ...
# 7      [[purpose, -, this, study, aims, to, propose, ...
# 8                      [[[, no, abstract, available, ]]]
# 9      [[the, use, of, social, networking, sites, (, ...
# 10     [[text, and, structural, data, mining, of, web...
# 11     [[mobile, phone, communication, as, digital, s...
# 12     [[this, paper, seeks, to, historicize, twitter...
# 13     [[online, review, forums, provide, consumers, ...
# 14     [[how, does, international, law, affect, state...
# 15     [[intra-urban, human, mobility, is, investigat...
# 16     [[mobile, and, pervasive, computing, technolog...
# 17     [[as, user, attributes, are, useful, for, appl...
# 18     [[learning, in, non-stationary, environments, ...
# 19     [[the, goal, of, sentiment, analysis, is, to, ...
# 20     [[sentiment, lexicon, is, a, crucial, resource...
# 21     [[geographically, annotated, social, media, is...
# 22     [[in, social, networking, services, (, snss, )...
# 23     [[sina, weibo, ,, the, most, popular, microblo...
# 24     [[microblogs, are, a, steadily, growing, ,, va...
# 25     [[purpose–the, purpose, of, this, paper, is, t...
# 26     [[the, relationship, between, bad, weather, an...
# 27     [[religiosity, is, a, powerful, force, shaping...
# 28     [[a, large, number, of, hashtags, are, generat...
# 29     [[social, scientists, are, often, interested, ...
# ...                                                  ...
# 20277  [[three, studies, presented, scenarios, to, la...
# 20278  [[we, compare, and, critique, two, measures, o...
# 20279  [[i, introduce, the, notion, of, ``, neglect, ...
# 20280  [[ninety-eight, australian, students, particip...
# 20281  [[we, perform, an, experimental, investigation...
# 20282  [[this, is, a, first, study, on, attachment, t...
# 20283  [[several, studies, propose, that, exemplar, r...
# 20284  [[judgments, and, decisions, under, uncertaint...
# 20285  [[we, claim, that, understanding, human, decis...
# 20286  [[the, assumption, that, people, possess, a, r...
# 20287  [[decision, research, in, psychology, has, tra...
# 20288  [[contrary, to, the, common, belief, that, mor...
# 20289  [[five, experiments, addressed, a, controversy...
# 20290  [[theoretical, equivalence, exists, among, var...
# 20291  [[this, article, presents, a, theory, of, reas...
# 20292  [[subjects, performed, a, decision, task, (, g...
# 20293  [[in, preventative, health, decisions, ,, such...
# 20294  [[this, study, employs, a, discrete, choice, e...
# 20295  [[people, live, in, a, world, in, which, they,...
# 20296  [[previous, studies, suggest, that, choices, a...
# 20297  [[the, present, article, investigates, the, ef...
# 20298  [[in, this, paper, i, explore, how, the, evolu...
# 20299  [[the, present, research, aimed, to, test, the...
# 20300  [[we, present, a, motivational, account, of, t...
# 20301  [[a, four-fold, classification, of, emotions, ...
# 20302  [[environmental, events, such, as, natural, di...
# 20303  [[affective, forecasting, with, respect, to, t...
# 20304                  [[[, no, abstract, available, ]]]
# 20305  [[according, to, siegrist, ,, earle, and, guts...
# 20306  [[decision, making, research, often, dichotomi...
#
# [20307 rows x 9 columns]

# %%
r1 = df_w2v.iloc[0]
r2 = df_w2v.iloc[-1]

# %%
compareRows([r1, r2], N, w2v = w2v)
#plt.savefig('images/comparisonTitle.pdf', format  = 'pdf', transparent=True)
plt.show()

# %%
r1 = df_w2v.iloc[-2]
r2 = df_w2v.iloc[1]
compareRows([r1, r2], N, w2v = w2v)
#plt.savefig('images/comparisonTitle.pdf', format  = 'pdf', transparent=True)
plt.show()

# %%
r1 = df_w2v.iloc[-2]
r2 = df_w2v.iloc[1]
compareRows([r1, r2], N, w2v = w2v, useTitle=False)
#plt.savefig('images/comparisonTitle.pdf', format  = 'pdf', transparent=True)
plt.show()
